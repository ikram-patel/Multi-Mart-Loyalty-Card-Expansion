# %%
# importing the necessary  libraries
import pandas as pd
import numpy as np

# %%
#Mount google drive to access data set
from google.colab import drive
drive.mount('/content/drive')

# # reading the data
data = pd.read_csv("/content/drive/MyDrive/DAB/DAB_322/Customer_Lifetime_Value_Dataset.csv", delimiter=',')

# # printing the head of the data
data.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    customerid firstpurchasedate lastpurchasedate  totalpurchases  \
# 0        8519        2021-12-31       2022-03-06               7
# 1       38152        2019-09-27       2023-02-02              20
# 2       19680        2021-06-13       2022-02-04              29
# 3       35744        2021-07-28       2022-08-21              15
# 4       11663        2021-01-19       2022-03-10              13
#
#    totalrevenue              referralsource  churnindicator  discountsused  \
# 0         11670       Online advertisements               0              2
# 1          5260  Traditional media outreach               1              6
# 2          9790     Influencer endorsements               0              2
# 3          9591     Influencer endorsements               0              5
# ...

# %%
#Checking productcategory data
data.productcategory
# Out:
# 0       Q02
# 1       F76
# 2       X04
# 3       A25
# 4       A16
#        ...
# 9995    K06
# 9996    I03
# 9997    W21
# 9998    Z44
# 9999    H78
# Name: productcategory, Length: 10000, dtype: object

# %%
#Create a new column to group productcategory data
data['products'] = data['productcategory'].str[0]

# %%
#Display new column
data[['products','productcategory']]
# Out:
#      products productcategory
# 0           Q             Q02
# 1           F             F76
# 2           X             X04
# 3           A             A25
# 4           A             A16
# ...       ...             ...
# 9995        K             K06
# 9996        I             I03
# 9997        W             W21
# 9998        Z             Z44
# 9999        H             H78
#
# [10000 rows x 2 columns]

# %%
# Create a new column 'rounded_feedbackscore' containing the rounded values
data['rounded_feedbackscore'] = data['feedbackscore'].round()

# Display the updated dataframe
data[['customerid','feedbackscore','rounded_feedbackscore']]
# Out:
#       customerid  feedbackscore  rounded_feedbackscore
# 0           8519       4.729998                    5.0
# 1          38152       4.184512                    4.0
# 2          19680       4.346640                    4.0
# 3          35744       5.000000                    5.0
# 4          11663       4.482089                    4.0
# ...          ...            ...                    ...
# 9995       21419       5.000000                    5.0
# 9996       24140       2.747824                    3.0
# 9997       32519       4.019456                    4.0
# 9998       47248       4.401005                    4.0
# 9999       44996       4.257398                    4.0
#
# [10000 rows x 3 columns]

# %%
#Count of Feedback score
data['rounded_feedbackscore'].value_counts()
# Out:
# 5.0    6675
# 4.0    1951
# 3.0     646
# 2.0     535
# 1.0     193
# Name: rounded_feedbackscore, dtype: int64

# %%
#Final transformed data
data.head()
# Out:
#    customerid firstpurchasedate lastpurchasedate  totalpurchases  \
# 0        8519        2021-12-31       2022-03-06               7
# 1       38152        2019-09-27       2023-02-02              20
# 2       19680        2021-06-13       2022-02-04              29
# 3       35744        2021-07-28       2022-08-21              15
# 4       11663        2021-01-19       2022-03-10              13
#
#    totalrevenue              referralsource  churnindicator  discountsused  \
# 0         11670       Online advertisements               0              2
# 1          5260  Traditional media outreach               1              6
# 2          9790     Influencer endorsements               0              2
# 3          9591     Influencer endorsements               0              5
# 4         10134               Word of mouth               0              3
#
#   productcategory responsetolastcampaign  feedbackscore  \
# 0             Q02                ignored       4.729998
# ...

# %%
data.to_csv("/content/drive/MyDrive/DAB/DAB_322/Retail_store_Dataset.csv", index=False)
